# %% [markdown]
# # 학습 목표
# 1. AnoGAN으로 테스트 화상과 가장 비슷한 화상을 생성하는 노이즈 z를 구하는 방법을 이해한다
#
# 2. AnoGAN을 구현하고, 필기체 숫자 화상으로 이상 탐지를 생성할 수 있다

# %% [markdown]
# # 사전 준비

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/MyDrive/Colab Notebooks/만들면서 배우는 파이토치 딥러닝/6. GAN을 활용한 이상 화상 탐지"
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/만들면서 배우는 파이토치 딥러닝/6. GAN을 활용한 이상 화상 탐지

# %%
import os
os.getcwd()
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/만들면서 배우는 파이토치 딥러닝/6. GAN을 활용한 이상 화상 탐지'

# %%
# 패키지 import
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Generator 구현

# %%
class Generator(nn.Module):

  def __init__(self, z_dim = 20, image_size = 64):
    super(Generator, self).__init__()

    self.layer1 = nn.Sequential(
        nn.ConvTranspose2d(z_dim, image_size * 8,
                           kernel_size = 4, stride = 1),
        nn.BatchNorm2d(image_size * 8),
        nn.ReLU(inplace = True))
    
    
    self.layer2 = nn.Sequential(
        nn.ConvTranspose2d(image_size * 8, image_size * 4,
                          kernel_size = 4, stride = 2, padding = 1),
        nn.BatchNorm2d(image_size * 4),
        nn.ReLU(inplace = True))
    

    self.layer3 = nn.Sequential(
        nn.ConvTranspose2d(image_size * 4, image_size * 2,
                           kernel_size = 4, stride = 2, padding = 1),
        nn.BatchNorm2d(image_size * 2),
        nn.ReLU(inplace=True))
    
    self.layer4 = nn.Sequential(
        nn.ConvTranspose2d(image_size * 2, image_size,
                           kernel_size = 4, stride = 2, padding = 1),
        nn.BatchNorm2d(image_size),
        nn.ReLU(inplace = True))
    

    self.last = nn.Sequential(
        nn.ConvTranspose2d(image_size, 1, kernel_size = 4,
                           stride = 2, padding = 1),
        nn.Tanh())
    
  def forward(self, z):
      out = self.layer1(z)
      out = self.layer2(out)
      out = self.layer3(out)
      out = self.layer4(out)
      out = self.last(out)

      return out

# %%
# 동작 확인
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim = 20, image_size = 64)

# 입력 난수 생성
input_z = torch.randn(1, 20)

# 텐서 사이즈를 (1, 20, 1, 1)로 변형
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 가짜 화상을 출력
fake_images = G(input_z)
print(fake_images[0][0], fake_images.shape)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()
# Out:
# tensor([[ 0.1821,  0.2989, -0.0760,  ...,  0.0837,  0.3263,  0.1843],
#         [-0.0038,  0.5154,  0.2928,  ...,  0.1251, -0.4567,  0.4683],
#         [-0.1521, -0.7209,  0.7380,  ...,  0.1142,  0.7871,  0.2145],
#         ...,
#         [ 0.0998,  0.5140, -0.4481,  ..., -0.2331, -0.0996,  0.3648],
#         [-0.2403,  0.7768,  0.9739,  ...,  0.6266,  0.3870,  0.1894],
#         [-0.1483,  0.3894,  0.0909,  ...,  0.3061,  0.1288,  0.2070]],
#        grad_fn=<SelectBackward0>) torch.Size([1, 1, 64, 64])

# %% [markdown]
# # Discriminator 구현

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim = 20, image_size = 64):
      super(Discriminator, self).__init__()

      self.layer1 = nn.Sequential(
          nn.Conv2d(1, image_size, kernel_size = 4,
                    stride = 2, padding = 1),
          nn.LeakyReLU(0.1, inplace = True))
      # 주의 : 흑백 화상이므로 입력 채널은 하나 뿐임

      self.layer2 = nn.Sequential(
          nn.Conv2d(image_size, image_size * 2, kernel_size = 4,
                    stride = 2, padding = 1),
          nn.LeakyReLU(0.1, inplace = True))
      
      self.layer3 = nn.Sequential(
          nn.Conv2d(image_size * 2, image_size * 4, kernel_size = 4,
                    stride = 2, padding = 1),
          nn.LeakyReLU(0.1, inplace = True))
      
      self.layer4 = nn.Sequential(
          nn.Conv2d(image_size * 4, image_size * 8, kernel_size = 4,
                    stride = 2, padding = 1),
          nn.LeakyReLU(0.1, inplace = True))
      
      self.last = nn.Conv2d(image_size * 8, 1, kernel_size = 4, stride = 1)


    def forward(self, x):
      out = self.layer1(x)
      out = self.layer2(out)
      out = self.layer3(out)
      out = self.layer4(out)

      feature = out # 최후에 채널을 하나로 집약
      feature = feature.view(feature.size()[0], -1) # 2차원으로 반환

      out = self.last(out)

      return out, feature

# %%
# 동작 확인
D = Discriminator(z_dim = 20, image_size = 64)

# 가짜 화상 생성
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 가짜 화상을 D에 입력
d_out = D(fake_images)
print(d_out)

# 출력 d_out에 Sigmoid를 곱해 0에서 1로 변환
print(nn.Sigmoid()(d_out[0]))

# feature
print(d_out[1].shape)
# Out:
# (tensor([[[[0.0264]]]], grad_fn=<ConvolutionBackward0>), tensor([[ 0.0053, -0.0028,  0.0004,  ..., -0.0029, -0.0048, -0.0028]],
#        grad_fn=<ViewBackward0>))
# tensor([[[[0.5066]]]], grad_fn=<SigmoidBackward0>)
# torch.Size([1, 8192])

# %% [markdown]
# # DataLoader 작성

# %%
def make_datapath_list():
  """ 학습 및 검증 화상 데이터와 어노테이션 데이터의 파일 경로 리스트를 작성한다."""

  train_img_list = list() # 화상 파일 경로를 저장

  for img_idx in range(200):
    img_path = "./data/img_78/img_7_" + str(img_idx) + '.jpg'
    train_img_list.append(img_path)

    img_path = "./data/img_78/img_8_" + str(img_idx) + '.jpg'
    train_img_list.append(img_path)

  return train_img_list

# %%
class ImageTransform():
    """화상의 전처리 클래스"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """화상의 Dataset 클래스. PyTorch의 Dataset 클래스를 상속"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''화상 매수를 반환한다'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''전처리한 화상의 Tensor 형식 데이터 취득'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [높이][폭]흑백

        # 화상 전처리
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoader 작성과 동작 확인

# 파일 리스트를 작성
train_img_list=make_datapath_list()

# Dataset 작성
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoader 작성
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 동작 확인
batch_iterator = iter(train_dataloader)  # 반복자로 변환
imges = next(batch_iterator)  # 1번째 요소를 꺼낸다
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %%
train_img_list
# Out:
# ['./data/img_78/img_7_0.jpg',
#  './data/img_78/img_8_0.jpg',
#  './data/img_78/img_7_1.jpg',
#  './data/img_78/img_8_1.jpg',
#  './data/img_78/img_7_2.jpg',
#  './data/img_78/img_8_2.jpg',
#  './data/img_78/img_7_3.jpg',
#  './data/img_78/img_8_3.jpg',
#  './data/img_78/img_7_4.jpg',
#  './data/img_78/img_8_4.jpg',
#  './data/img_78/img_7_5.jpg',
#  './data/img_78/img_8_5.jpg',
#  './data/img_78/img_7_6.jpg',
#  './data/img_78/img_8_6.jpg',
#  './data/img_78/img_7_7.jpg',
#  './data/img_78/img_8_7.jpg',
#  './data/img_78/img_7_8.jpg',
#  './data/img_78/img_8_8.jpg',
#  './data/img_78/img_7_9.jpg',
#  './data/img_78/img_8_9.jpg',
#  './data/img_78/img_7_10.jpg',
#  './data/img_78/img_8_10.jpg',
#  './data/img_78/img_7_11.jpg',
#  './data/img_78/img_8_11.jpg',
#  './data/img_78/img_7_12.jpg',
#  './data/img_78/img_8_12.jpg',
#  './data/img_78/img_7_13.jpg',
#  './data/img_78/img_8_13.jpg',
#  './data/img_78/img_7_14.jpg',
#  './data/img_78/img_8_14.jpg',
#  './data/img_78/img_7_15.jpg',
#  './data/img_78/img_8_15.jpg',
#  './data/img_78/img_7_16.jpg',
#  './data/img_78/img_8_16.jpg',
#  './data/img_78/img_7_17.jpg',
#  './data/img_78/img_8_17.jpg',
#  './data/img_78/img_7_18.jpg',
#  './data/img_78/img_8_18.jpg',
#  './data/img_78/img_7_19.jpg',
#  './data/img_78/img_8_19.jpg',
#  './data/img_78/img_7_20.jpg',
#  './data/img_78/img_8_20.jpg',
#  './data/img_78/img_7_21.jpg',
#  './data/img_78/img_8_21.jpg',
#  './data/img_78/img_7_22.jpg',
#  './data/img_78/img_8_22.jpg',
#  './data/img_78/img_7_23.jpg',
#  './data/img_78/img_8_23.jpg',
#  './data/img_78/img_7_24.jpg',
#  './data/img_78/img_8_24.jpg',
#  './data/img_78/img_7_25.jpg',
#  './data/img_78/img_8_25.jpg',
#  './data/img_78/img_7_26.jpg',
#  './data/img_78/img_8_26.jpg',
#  './data/img_78/img_7_27.jpg',
#  './data/img_78/img_8_27.jpg',
#  './data/img_78/img_7_28.jpg',
#  './data/img_78/img_8_28.jpg',
#  './data/img_78/img_7_29.jpg',
#  './data/img_78/img_8_29.jpg',
#  './data/img_78/img_7_30.jpg',
#  './data/img_78/img_8_30.jpg',
#  './data/img_78/img_7_31.jpg',
#  './data/img_78/img_8_31.jpg',
#  './data/img_78/img_7_32.jpg',
#  './data/img_78/img_8_32.jpg',
#  './data/img_78/img_7_33.jpg',
#  './data/img_78/img_8_33.jpg',
#  './data/img_78/img_7_34.jpg',
#  './data/img_78/img_8_34.jpg',
#  './data/img_78/img_7_35.jpg',
#  './data/img_78/img_8_35.jpg',
#  './data/img_78/img_7_36.jpg',
#  './data/img_78/img_8_36.jpg',
#  './data/img_78/img_7_37.jpg',
#  './data/img_78/img_8_37.jpg',
#  './data/img_78/img_7_38.jpg',
#  './data/img_78/img_8_38.jpg',
#  './data/img_78/img_7_39.jpg',
#  './data/img_78/img_8_39.jpg',
#  './data/img_78/img_7_40.jpg',
#  './data/img_78/img_8_40.jpg',
#  './data/img_78/img_7_41.jpg',
#  './data/img_78/img_8_41.jpg',
#  './data/img_78/img_7_42.jpg',
#  './data/img_78/img_8_42.jpg',
#  './data/img_78/img_7_43.jpg',
#  './data/img_78/img_8_43.jpg',
#  './data/img_78/img_7_44.jpg',
#  './data/img_78/img_8_44.jpg',
#  './data/img_78/img_7_45.jpg',
#  './data/img_78/img_8_45.jpg',
#  './data/img_78/img_7_46.jpg',
#  './data/img_78/img_8_46.jpg',
#  './data/img_78/img_7_47.jpg',
#  './data/img_78/img_8_47.jpg',
#  './data/img_78/img_7_48.jpg',
#  './data/img_78/img_8_48.jpg',
#  './data/img_78/img_7_49.jpg',
#  './data/img_78/img_8_49.jpg',
#  './data/img_78/img_7_50.jpg',
#  './data/img_78/img_8_50.jpg',
#  './data/img_78/img_7_51.jpg',
#  './data/img_78/img_8_51.jpg',
#  './data/img_78/img_7_52.jpg',
#  './data/img_78/img_8_52.jpg',
#  './data/img_78/img_7_53.jpg',
#  './data/img_78/img_8_53.jpg',
#  './data/img_78/img_7_54.jpg',
#  './data/img_78/img_8_54.jpg',
#  './data/img_78/img_7_55.jpg',
#  './data/img_78/img_8_55.jpg',
#  './data/img_78/img_7_56.jpg',
#  './data/img_78/img_8_56.jpg',
#  './data/img_78/img_7_57.jpg',
#  './data/img_78/img_8_57.jpg',
#  './data/img_78/img_7_58.jpg',
#  './data/img_78/img_8_58.jpg',
#  './data/img_78/img_7_59.jpg',
#  './data/img_78/img_8_59.jpg',
#  './data/img_78/img_7_60.jpg',
#  './data/img_78/img_8_60.jpg',
#  './data/img_78/img_7_61.jpg',
#  './data/img_78/img_8_61.jpg',
#  './data/img_78/img_7_62.jpg',
#  './data/img_78/img_8_62.jpg',
#  './data/img_78/img_7_63.jpg',
#  './data/img_78/img_8_63.jpg',
#  './data/img_78/img_7_64.jpg',
#  './data/img_78/img_8_64.jpg',
#  './data/img_78/img_7_65.jpg',
#  './data/img_78/img_8_65.jpg',
#  './data/img_78/img_7_66.jpg',
#  './data/img_78/img_8_66.jpg',
#  './data/img_78/img_7_67.jpg',
#  './data/img_78/img_8_67.jpg',
#  './data/img_78/img_7_68.jpg',
#  './data/img_78/img_8_68.jpg',
#  './data/img_78/img_7_69.jpg',
#  './data/img_78/img_8_69.jpg',
#  './data/img_78/img_7_70.jpg',
#  './data/img_78/img_8_70.jpg',
#  './data/img_78/img_7_71.jpg',
#  './data/img_78/img_8_71.jpg',
#  './data/img_78/img_7_72.jpg',
#  './data/img_78/img_8_72.jpg',
#  './data/img_78/img_7_73.jpg',
#  './data/img_78/img_8_73.jpg',
#  './data/img_78/img_7_74.jpg',
#  './data/img_78/img_8_74.jpg',
#  './data/img_78/img_7_75.jpg',
#  './data/img_78/img_8_75.jpg',
#  './data/img_78/img_7_76.jpg',
#  './data/img_78/img_8_76.jpg',
#  './data/img_78/img_7_77.jpg',
#  './data/img_78/img_8_77.jpg',
#  './data/img_78/img_7_78.jpg',
#  './data/img_78/img_8_78.jpg',
#  './data/img_78/img_7_79.jpg',
#  './data/img_78/img_8_79.jpg',
#  './data/img_78/img_7_80.jpg',
#  './data/img_78/img_8_80.jpg',
#  './data/img_78/img_7_81.jpg',
#  './data/img_78/img_8_81.jpg',
#  './data/img_78/img_7_82.jpg',
#  './data/img_78/img_8_82.jpg',
#  './data/img_78/img_7_83.jpg',
#  './data/img_78/img_8_83.jpg',
#  './data/img_78/img_7_84.jpg',
#  './data/img_78/img_8_84.jpg',
#  './data/img_78/img_7_85.jpg',
#  './data/img_78/img_8_85.jpg',
#  './data/img_78/img_7_86.jpg',
#  './data/img_78/img_8_86.jpg',
#  './data/img_78/img_7_87.jpg',
#  './data/img_78/img_8_87.jpg',
#  './data/img_78/img_7_88.jpg',
#  './data/img_78/img_8_88.jpg',
#  './data/img_78/img_7_89.jpg',
#  './data/img_78/img_8_89.jpg',
#  './data/img_78/img_7_90.jpg',
#  './data/img_78/img_8_90.jpg',
#  './data/img_78/img_7_91.jpg',
#  './data/img_78/img_8_91.jpg',
#  './data/img_78/img_7_92.jpg',
#  './data/img_78/img_8_92.jpg',
#  './data/img_78/img_7_93.jpg',
#  './data/img_78/img_8_93.jpg',
#  './data/img_78/img_7_94.jpg',
#  './data/img_78/img_8_94.jpg',
#  './data/img_78/img_7_95.jpg',
#  './data/img_78/img_8_95.jpg',
#  './data/img_78/img_7_96.jpg',
#  './data/img_78/img_8_96.jpg',
#  './data/img_78/img_7_97.jpg',
#  './data/img_78/img_8_97.jpg',
#  './data/img_78/img_7_98.jpg',
#  './data/img_78/img_8_98.jpg',
#  './data/img_78/img_7_99.jpg',
#  './data/img_78/img_8_99.jpg',
#  './data/img_78/img_7_100.jpg',
#  './data/img_78/img_8_100.jpg',
#  './data/img_78/img_7_101.jpg',
#  './data/img_78/img_8_101.jpg',
#  './data/img_78/img_7_102.jpg',
#  './data/img_78/img_8_102.jpg',
#  './data/img_78/img_7_103.jpg',
#  './data/img_78/img_8_103.jpg',
#  './data/img_78/img_7_104.jpg',
#  './data/img_78/img_8_104.jpg',
#  './data/img_78/img_7_105.jpg',
#  './data/img_78/img_8_105.jpg',
#  './data/img_78/img_7_106.jpg',
#  './data/img_78/img_8_106.jpg',
#  './data/img_78/img_7_107.jpg',
#  './data/img_78/img_8_107.jpg',
#  './data/img_78/img_7_108.jpg',
#  './data/img_78/img_8_108.jpg',
#  './data/img_78/img_7_109.jpg',
#  './data/img_78/img_8_109.jpg',
#  './data/img_78/img_7_110.jpg',
#  './data/img_78/img_8_110.jpg',
#  './data/img_78/img_7_111.jpg',
#  './data/img_78/img_8_111.jpg',
#  './data/img_78/img_7_112.jpg',
#  './data/img_78/img_8_112.jpg',
#  './data/img_78/img_7_113.jpg',
#  './data/img_78/img_8_113.jpg',
#  './data/img_78/img_7_114.jpg',
#  './data/img_78/img_8_114.jpg',
#  './data/img_78/img_7_115.jpg',
#  './data/img_78/img_8_115.jpg',
#  './data/img_78/img_7_116.jpg',
#  './data/img_78/img_8_116.jpg',
#  './data/img_78/img_7_117.jpg',
#  './data/img_78/img_8_117.jpg',
#  './data/img_78/img_7_118.jpg',
#  './data/img_78/img_8_118.jpg',
#  './data/img_78/img_7_119.jpg',
#  './data/img_78/img_8_119.jpg',
#  './data/img_78/img_7_120.jpg',
#  './data/img_78/img_8_120.jpg',
#  './data/img_78/img_7_121.jpg',
#  './data/img_78/img_8_121.jpg',
#  './data/img_78/img_7_122.jpg',
#  './data/img_78/img_8_122.jpg',
#  './data/img_78/img_7_123.jpg',
#  './data/img_78/img_8_123.jpg',
#  './data/img_78/img_7_124.jpg',
#  './data/img_78/img_8_124.jpg',
#  './data/img_78/img_7_125.jpg',
#  './data/img_78/img_8_125.jpg',
#  './data/img_78/img_7_126.jpg',
#  './data/img_78/img_8_126.jpg',
#  './data/img_78/img_7_127.jpg',
#  './data/img_78/img_8_127.jpg',
#  './data/img_78/img_7_128.jpg',
#  './data/img_78/img_8_128.jpg',
#  './data/img_78/img_7_129.jpg',
#  './data/img_78/img_8_129.jpg',
#  './data/img_78/img_7_130.jpg',
#  './data/img_78/img_8_130.jpg',
#  './data/img_78/img_7_131.jpg',
#  './data/img_78/img_8_131.jpg',
#  './data/img_78/img_7_132.jpg',
#  './data/img_78/img_8_132.jpg',
#  './data/img_78/img_7_133.jpg',
#  './data/img_78/img_8_133.jpg',
#  './data/img_78/img_7_134.jpg',
#  './data/img_78/img_8_134.jpg',
#  './data/img_78/img_7_135.jpg',
#  './data/img_78/img_8_135.jpg',
#  './data/img_78/img_7_136.jpg',
#  './data/img_78/img_8_136.jpg',
#  './data/img_78/img_7_137.jpg',
#  './data/img_78/img_8_137.jpg',
#  './data/img_78/img_7_138.jpg',
#  './data/img_78/img_8_138.jpg',
#  './data/img_78/img_7_139.jpg',
#  './data/img_78/img_8_139.jpg',
#  './data/img_78/img_7_140.jpg',
#  './data/img_78/img_8_140.jpg',
#  './data/img_78/img_7_141.jpg',
#  './data/img_78/img_8_141.jpg',
#  './data/img_78/img_7_142.jpg',
#  './data/img_78/img_8_142.jpg',
#  './data/img_78/img_7_143.jpg',
#  './data/img_78/img_8_143.jpg',
#  './data/img_78/img_7_144.jpg',
#  './data/img_78/img_8_144.jpg',
#  './data/img_78/img_7_145.jpg',
#  './data/img_78/img_8_145.jpg',
#  './data/img_78/img_7_146.jpg',
#  './data/img_78/img_8_146.jpg',
#  './data/img_78/img_7_147.jpg',
#  './data/img_78/img_8_147.jpg',
#  './data/img_78/img_7_148.jpg',
#  './data/img_78/img_8_148.jpg',
#  './data/img_78/img_7_149.jpg',
#  './data/img_78/img_8_149.jpg',
#  './data/img_78/img_7_150.jpg',
#  './data/img_78/img_8_150.jpg',
#  './data/img_78/img_7_151.jpg',
#  './data/img_78/img_8_151.jpg',
#  './data/img_78/img_7_152.jpg',
#  './data/img_78/img_8_152.jpg',
#  './data/img_78/img_7_153.jpg',
#  './data/img_78/img_8_153.jpg',
#  './data/img_78/img_7_154.jpg',
#  './data/img_78/img_8_154.jpg',
#  './data/img_78/img_7_155.jpg',
#  './data/img_78/img_8_155.jpg',
#  './data/img_78/img_7_156.jpg',
#  './data/img_78/img_8_156.jpg',
#  './data/img_78/img_7_157.jpg',
#  './data/img_78/img_8_157.jpg',
#  './data/img_78/img_7_158.jpg',
#  './data/img_78/img_8_158.jpg',
#  './data/img_78/img_7_159.jpg',
#  './data/img_78/img_8_159.jpg',
#  './data/img_78/img_7_160.jpg',
#  './data/img_78/img_8_160.jpg',
#  './data/img_78/img_7_161.jpg',
#  './data/img_78/img_8_161.jpg',
#  './data/img_78/img_7_162.jpg',
#  './data/img_78/img_8_162.jpg',
#  './data/img_78/img_7_163.jpg',
#  './data/img_78/img_8_163.jpg',
#  './data/img_78/img_7_164.jpg',
#  './data/img_78/img_8_164.jpg',
#  './data/img_78/img_7_165.jpg',
#  './data/img_78/img_8_165.jpg',
#  './data/img_78/img_7_166.jpg',
#  './data/img_78/img_8_166.jpg',
#  './data/img_78/img_7_167.jpg',
#  './data/img_78/img_8_167.jpg',
#  './data/img_78/img_7_168.jpg',
#  './data/img_78/img_8_168.jpg',
#  './data/img_78/img_7_169.jpg',
#  './data/img_78/img_8_169.jpg',
#  './data/img_78/img_7_170.jpg',
#  './data/img_78/img_8_170.jpg',
#  './data/img_78/img_7_171.jpg',
#  './data/img_78/img_8_171.jpg',
#  './data/img_78/img_7_172.jpg',
#  './data/img_78/img_8_172.jpg',
#  './data/img_78/img_7_173.jpg',
#  './data/img_78/img_8_173.jpg',
#  './data/img_78/img_7_174.jpg',
#  './data/img_78/img_8_174.jpg',
#  './data/img_78/img_7_175.jpg',
#  './data/img_78/img_8_175.jpg',
#  './data/img_78/img_7_176.jpg',
#  './data/img_78/img_8_176.jpg',
#  './data/img_78/img_7_177.jpg',
#  './data/img_78/img_8_177.jpg',
#  './data/img_78/img_7_178.jpg',
#  './data/img_78/img_8_178.jpg',
#  './data/img_78/img_7_179.jpg',
#  './data/img_78/img_8_179.jpg',
#  './data/img_78/img_7_180.jpg',
#  './data/img_78/img_8_180.jpg',
#  './data/img_78/img_7_181.jpg',
#  './data/img_78/img_8_181.jpg',
#  './data/img_78/img_7_182.jpg',
#  './data/img_78/img_8_182.jpg',
#  './data/img_78/img_7_183.jpg',
#  './data/img_78/img_8_183.jpg',
#  './data/img_78/img_7_184.jpg',
#  './data/img_78/img_8_184.jpg',
#  './data/img_78/img_7_185.jpg',
#  './data/img_78/img_8_185.jpg',
#  './data/img_78/img_7_186.jpg',
#  './data/img_78/img_8_186.jpg',
#  './data/img_78/img_7_187.jpg',
#  './data/img_78/img_8_187.jpg',
#  './data/img_78/img_7_188.jpg',
#  './data/img_78/img_8_188.jpg',
#  './data/img_78/img_7_189.jpg',
#  './data/img_78/img_8_189.jpg',
#  './data/img_78/img_7_190.jpg',
#  './data/img_78/img_8_190.jpg',
#  './data/img_78/img_7_191.jpg',
#  './data/img_78/img_8_191.jpg',
#  './data/img_78/img_7_192.jpg',
#  './data/img_78/img_8_192.jpg',
#  './data/img_78/img_7_193.jpg',
#  './data/img_78/img_8_193.jpg',
#  './data/img_78/img_7_194.jpg',
#  './data/img_78/img_8_194.jpg',
#  './data/img_78/img_7_195.jpg',
#  './data/img_78/img_8_195.jpg',
#  './data/img_78/img_7_196.jpg',
#  './data/img_78/img_8_196.jpg',
#  './data/img_78/img_7_197.jpg',
#  './data/img_78/img_8_197.jpg',
#  './data/img_78/img_7_198.jpg',
#  './data/img_78/img_8_198.jpg',
#  './data/img_78/img_7_199.jpg',
#  './data/img_78/img_8_199.jpg']

# %%
# 네트워크 초기화
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2d 초기화
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2d 초기화
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 초기화 실시
G.apply(weights_init)
D.apply(weights_init)

print("네트워크 초기화 완료")
# Out:
# 네트워크 초기화 완료

# %%
from torch.nn import BCEWithLogitsLoss

# 모델을 학습시키는 함수를 작성
def train_model(G, D, dataloader, num_epochs):

    # GPU가 사용 가능한지 확인
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("사용 장치: ", device)

    # 최적화 기법 설정
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # 오차함수 정의
    criterion = BCEWithLogitsLoss(reduction='mean')

    # 파라미터를 하드코딩
    z_dim = 20
    mini_batch_size = 64

    # 네트워크를 GPU로
    G.to(device)
    D.to(device)

    G.train()  # 모델을 훈련 모드로
    D.train()  # 모델을 훈련 모드로

    # 네트워크가 어느 정도 고정되면, 고속화시킨다
    torch.backends.cudnn.benchmark = True

    # 화상의 매수
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # 반복 카운터 설정
    iteration = 1
    logs = []

    # epoch 루프
    for epoch in range(num_epochs):

        # 개시 시간을 저장
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epoch의 손실합
        epoch_d_loss = 0.0  # epoch의 손실합

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('(train)')

        # 데이터 로더에서 minibatch씩 꺼내는 루프
        for imges in dataloader:

            # --------------------
            # 1. Discriminator 학습
            # --------------------
            # 미니 배치 크기가 1이면, 배치 노멀라이제이션에서 에러가 발생하므로 피한다
            if imges.size()[0] == 1:
                continue

            # GPU가 사용 가능하면 GPU로 데이터를 보낸다
            imges = imges.to(device)

            # 정답 라벨과 가짜 라벨 작성
            # epoch의 마지막 반복은 미니 배치 수가 줄어든다
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 진짜 화상을 판정
            d_out_real, _ = D(imges)

            # 가짜 화상을 생성해 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)


            # 오차를 계산
            d_loss_real = criterion(d_out_real.view(-1).float(), label_real.float())
            d_loss_fake = criterion(d_out_fake.view(-1).float(), label_fake.float())
            d_loss = d_loss_real + d_loss_fake

            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()

            d_loss.backward()
            d_optimizer.step()

            # --------------------
            # 2. Generator 학습
            # --------------------
            # 가짜 화상을 생성해 판정
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            # 오차를 계산
            g_loss = criterion(d_out_fake.view(-1).float(), label_real.float())

            # 역전파
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # --------------------
            # 3. 기록
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # epoch의 phase별 loss와 정답률
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    
    print("총 반복 횟수: ", iteration)

    return G, D

# %%
# 학습 및 검증을 실행한다
# 8분 정도 걸립니다
num_epochs = 300
G_update, D_update = train_model(
    G, D, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 사용 장치:  cuda:0
# -------------
# Epoch 0/300
# -------------
# (train)
# -------------
# epoch 0 || Epoch_D_Loss:0.0707 ||Epoch_G_Loss:0.2545
# timer:  49.9388 sec.
# -------------
# Epoch 1/300
# -------------
# (train)
# -------------
# epoch 1 || Epoch_D_Loss:0.0044 ||Epoch_G_Loss:0.5819
# timer:  1.0907 sec.
# -------------
# Epoch 2/300
# -------------
# (train)
# -------------
# epoch 2 || Epoch_D_Loss:0.0005 ||Epoch_G_Loss:0.7038
# timer:  1.0296 sec.
# -------------
# Epoch 3/300
# -------------
# (train)
# -------------
# epoch 3 || Epoch_D_Loss:0.0459 ||Epoch_G_Loss:0.6420
# timer:  1.0194 sec.
# -------------
# Epoch 4/300
# -------------
# (train)
# -------------
# epoch 4 || Epoch_D_Loss:0.0003 ||Epoch_G_Loss:0.7444
# timer:  1.0278 sec.
# -------------
# Epoch 5/300
# -------------
# (train)
# -------------
# epoch 5 || Epoch_D_Loss:0.1113 ||Epoch_G_Loss:0.6138
# timer:  1.0431 sec.
# -------------
# Epoch 6/300
# -------------
# (train)
# -------------
# epoch 6 || Epoch_D_Loss:0.0851 ||Epoch_G_Loss:0.0852
# timer:  1.0652 sec.
# -------------
# Epoch 7/300
# -------------
# (train)
# -------------
# epoch 7 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.1105
# timer:  1.0760 sec.
# -------------
# Epoch 8/300
# -------------
# (train)
# -------------
# epoch 8 || Epoch_D_Loss:0.1095 ||Epoch_G_Loss:0.1283
# timer:  1.0295 sec.
# -------------
# Epoch 9/300
# -------------
# (train)
# -------------
# epoch 9 || Epoch_D_Loss:0.0412 ||Epoch_G_Loss:0.1729
# timer:  1.0424 sec.
# -------------
# Epoch 10/300
# -------------
# (train)
# -------------
# epoch 10 || Epoch_D_Loss:0.0159 ||Epoch_G_Loss:0.3028
# timer:  1.0580 sec.
# -------------
# Epoch 11/300
# -------------
# (train)
# -------------
# epoch 11 || Epoch_D_Loss:0.0260 ||Epoch_G_Loss:0.4273
# timer:  1.0772 sec.
# -------------
# Epoch 12/300
# -------------
# (train)
# -------------
# epoch 12 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.5860
# timer:  1.0439 sec.
# -------------
# Epoch 13/300
# -------------
# (train)
# -------------
# epoch 13 || Epoch_D_Loss:0.0828 ||Epoch_G_Loss:0.3025
# timer:  1.0514 sec.
# -------------
# Epoch 14/300
# -------------
# (train)
# -------------
# epoch 14 || Epoch_D_Loss:0.0057 ||Epoch_G_Loss:0.5071
# timer:  1.0536 sec.
# -------------
# Epoch 15/300
# -------------
# (train)
# -------------
# epoch 15 || Epoch_D_Loss:0.1873 ||Epoch_G_Loss:0.4912
# timer:  1.0534 sec.
# -------------
# Epoch 16/300
# -------------
# (train)
# -------------
# epoch 16 || Epoch_D_Loss:0.0134 ||Epoch_G_Loss:0.3677
# timer:  1.0484 sec.
# -------------
# Epoch 17/300
# -------------
# (train)
# -------------
# epoch 17 || Epoch_D_Loss:0.0075 ||Epoch_G_Loss:0.4874
# timer:  1.0492 sec.
# -------------
# Epoch 18/300
# -------------
# (train)
# -------------
# epoch 18 || Epoch_D_Loss:0.0331 ||Epoch_G_Loss:0.4193
# timer:  1.0326 sec.
# -------------
# Epoch 19/300
# -------------
# (train)
# -------------
# epoch 19 || Epoch_D_Loss:0.0029 ||Epoch_G_Loss:0.5051
# timer:  1.0473 sec.
# -------------
# Epoch 20/300
# -------------
# (train)
# -------------
# epoch 20 || Epoch_D_Loss:0.2546 ||Epoch_G_Loss:0.6205
# timer:  1.0359 sec.
# -------------
# Epoch 21/300
# -------------
# (train)
# -------------
# epoch 21 || Epoch_D_Loss:0.0248 ||Epoch_G_Loss:0.4029
# timer:  1.0358 sec.
# -------------
# Epoch 22/300
# -------------
# (train)
# -------------
# epoch 22 || Epoch_D_Loss:0.1066 ||Epoch_G_Loss:0.3801
# timer:  1.0333 sec.
# -------------
# Epoch 23/300
# -------------
# (train)
# -------------
# epoch 23 || Epoch_D_Loss:0.0124 ||Epoch_G_Loss:0.3939
# timer:  1.0275 sec.
# -------------
# Epoch 24/300
# -------------
# (train)
# -------------
# epoch 24 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.3388
# timer:  1.0338 sec.
# -------------
# Epoch 25/300
# -------------
# (train)
# -------------
# epoch 25 || Epoch_D_Loss:0.0294 ||Epoch_G_Loss:0.4334
# timer:  1.0252 sec.
# -------------
# Epoch 26/300
# -------------
# (train)
# -------------
# epoch 26 || Epoch_D_Loss:0.1653 ||Epoch_G_Loss:0.3919
# timer:  1.0344 sec.
# -------------
# Epoch 27/300
# -------------
# (train)
# -------------
# epoch 27 || Epoch_D_Loss:0.0313 ||Epoch_G_Loss:0.3347
# timer:  1.0564 sec.
# -------------
# Epoch 28/300
# -------------
# (train)
# -------------
# epoch 28 || Epoch_D_Loss:0.1020 ||Epoch_G_Loss:0.4030
# timer:  1.0365 sec.
# -------------
# Epoch 29/300
# -------------
# (train)
# -------------
# epoch 29 || Epoch_D_Loss:0.1289 ||Epoch_G_Loss:0.3065
# timer:  1.0331 sec.
# -------------
# Epoch 30/300
# -------------
# (train)
# -------------
# epoch 30 || Epoch_D_Loss:0.1010 ||Epoch_G_Loss:0.2778
# timer:  1.0383 sec.
# -------------
# Epoch 31/300
# -------------
# (train)
# -------------
# epoch 31 || Epoch_D_Loss:0.0447 ||Epoch_G_Loss:0.3561
# timer:  1.0405 sec.
# -------------
# Epoch 32/300
# -------------
# (train)
# -------------
# epoch 32 || Epoch_D_Loss:0.1613 ||Epoch_G_Loss:0.1559
# timer:  1.0197 sec.
# -------------
# Epoch 33/300
# -------------
# (train)
# -------------
# epoch 33 || Epoch_D_Loss:0.0277 ||Epoch_G_Loss:0.3027
# timer:  1.0312 sec.
# -------------
# Epoch 34/300
# -------------
# (train)
# -------------
# epoch 34 || Epoch_D_Loss:0.1291 ||Epoch_G_Loss:0.3471
# timer:  1.0216 sec.
# -------------
# Epoch 35/300
# -------------
# (train)
# -------------
# epoch 35 || Epoch_D_Loss:0.0989 ||Epoch_G_Loss:0.1989
# timer:  1.0118 sec.
# -------------
# Epoch 36/300
# -------------
# (train)
# -------------
# epoch 36 || Epoch_D_Loss:0.1174 ||Epoch_G_Loss:0.2550
# timer:  1.0210 sec.
# -------------
# Epoch 37/300
# -------------
# (train)
# -------------
# epoch 37 || Epoch_D_Loss:0.1119 ||Epoch_G_Loss:0.2380
# timer:  1.0223 sec.
# -------------
# Epoch 38/300
# -------------
# (train)
# -------------
# epoch 38 || Epoch_D_Loss:0.0835 ||Epoch_G_Loss:0.2141
# timer:  1.0254 sec.
# -------------
# Epoch 39/300
# -------------
# (train)
# -------------
# epoch 39 || Epoch_D_Loss:0.1124 ||Epoch_G_Loss:0.2140
# timer:  1.0407 sec.
# -------------
# Epoch 40/300
# -------------
# (train)
# -------------
# epoch 40 || Epoch_D_Loss:0.0961 ||Epoch_G_Loss:0.2109
# timer:  1.0347 sec.
# -------------
# Epoch 41/300
# -------------
# (train)
# -------------
# epoch 41 || Epoch_D_Loss:0.0891 ||Epoch_G_Loss:0.2233
# timer:  1.0212 sec.
# -------------
# Epoch 42/300
# -------------
# (train)
# -------------
# epoch 42 || Epoch_D_Loss:0.1002 ||Epoch_G_Loss:0.1578
# timer:  1.0052 sec.
# -------------
# Epoch 43/300
# -------------
# (train)
# -------------
# epoch 43 || Epoch_D_Loss:0.0999 ||Epoch_G_Loss:0.2249
# timer:  1.0190 sec.
# -------------
# Epoch 44/300
# -------------
# (train)
# -------------
# epoch 44 || Epoch_D_Loss:0.1035 ||Epoch_G_Loss:0.2183
# timer:  1.0021 sec.
# -------------
# Epoch 45/300
# -------------
# (train)
# -------------
# epoch 45 || Epoch_D_Loss:0.0798 ||Epoch_G_Loss:0.2339
# timer:  1.0140 sec.
# -------------
# Epoch 46/300
# -------------
# (train)
# -------------
# epoch 46 || Epoch_D_Loss:0.0964 ||Epoch_G_Loss:0.2087
# timer:  1.0294 sec.
# -------------
# Epoch 47/300
# -------------
# (train)
# -------------
# epoch 47 || Epoch_D_Loss:0.0704 ||Epoch_G_Loss:0.2299
# timer:  1.0103 sec.
# -------------
# Epoch 48/300
# -------------
# (train)
# -------------
# epoch 48 || Epoch_D_Loss:0.0974 ||Epoch_G_Loss:0.1866
# timer:  1.0123 sec.
# -------------
# Epoch 49/300
# -------------
# (train)
# -------------
# epoch 49 || Epoch_D_Loss:0.1183 ||Epoch_G_Loss:0.1878
# timer:  1.0126 sec.
# -------------
# Epoch 50/300
# -------------
# (train)
# -------------
# epoch 50 || Epoch_D_Loss:0.1161 ||Epoch_G_Loss:0.2163
# timer:  0.9977 sec.
# -------------
# Epoch 51/300
# -------------
# (train)
# -------------
# epoch 51 || Epoch_D_Loss:0.0986 ||Epoch_G_Loss:0.1590
# timer:  1.0198 sec.
# -------------
# Epoch 52/300
# -------------
# (train)
# -------------
# epoch 52 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.1875
# timer:  1.0208 sec.
# -------------
# Epoch 53/300
# -------------
# (train)
# -------------
# epoch 53 || Epoch_D_Loss:0.1180 ||Epoch_G_Loss:0.1658
# timer:  1.0070 sec.
# -------------
# Epoch 54/300
# -------------
# (train)
# -------------
# epoch 54 || Epoch_D_Loss:0.0984 ||Epoch_G_Loss:0.1563
# timer:  1.0234 sec.
# -------------
# Epoch 55/300
# -------------
# (train)
# -------------
# epoch 55 || Epoch_D_Loss:0.1154 ||Epoch_G_Loss:0.1631
# timer:  1.0110 sec.
# -------------
# Epoch 56/300
# -------------
# (train)
# -------------
# epoch 56 || Epoch_D_Loss:0.1136 ||Epoch_G_Loss:0.1353
# timer:  1.0072 sec.
# -------------
# Epoch 57/300
# -------------
# (train)
# -------------
# epoch 57 || Epoch_D_Loss:0.1154 ||Epoch_G_Loss:0.1591
# timer:  1.0085 sec.
# -------------
# Epoch 58/300
# -------------
# (train)
# -------------
# epoch 58 || Epoch_D_Loss:0.1115 ||Epoch_G_Loss:0.1372
# timer:  1.0362 sec.
# -------------
# Epoch 59/300
# -------------
# (train)
# -------------
# epoch 59 || Epoch_D_Loss:0.1268 ||Epoch_G_Loss:0.1491
# timer:  1.0122 sec.
# -------------
# Epoch 60/300
# -------------
# (train)
# -------------
# epoch 60 || Epoch_D_Loss:0.1021 ||Epoch_G_Loss:0.1551
# timer:  1.0021 sec.
# -------------
# Epoch 61/300
# -------------
# (train)
# -------------
# epoch 61 || Epoch_D_Loss:0.1167 ||Epoch_G_Loss:0.1382
# timer:  1.0233 sec.
# -------------
# Epoch 62/300
# -------------
# (train)
# -------------
# epoch 62 || Epoch_D_Loss:0.1125 ||Epoch_G_Loss:0.1746
# timer:  1.0335 sec.
# -------------
# Epoch 63/300
# -------------
# (train)
# -------------
# epoch 63 || Epoch_D_Loss:0.1000 ||Epoch_G_Loss:0.1547
# timer:  1.0276 sec.
# -------------
# Epoch 64/300
# -------------
# (train)
# -------------
# epoch 64 || Epoch_D_Loss:0.0976 ||Epoch_G_Loss:0.1542
# timer:  1.0046 sec.
# -------------
# Epoch 65/300
# -------------
# (train)
# -------------
# epoch 65 || Epoch_D_Loss:0.1213 ||Epoch_G_Loss:0.1595
# timer:  1.0092 sec.
# -------------
# Epoch 66/300
# -------------
# (train)
# -------------
# epoch 66 || Epoch_D_Loss:0.1016 ||Epoch_G_Loss:0.1771
# timer:  1.0139 sec.
# -------------
# Epoch 67/300
# -------------
# (train)
# -------------
# epoch 67 || Epoch_D_Loss:0.0967 ||Epoch_G_Loss:0.1625
# timer:  1.0113 sec.
# -------------
# Epoch 68/300
# -------------
# (train)
# -------------
# epoch 68 || Epoch_D_Loss:0.0921 ||Epoch_G_Loss:0.1842
# timer:  1.0046 sec.
# -------------
# Epoch 69/300
# -------------
# (train)
# -------------
# epoch 69 || Epoch_D_Loss:0.0838 ||Epoch_G_Loss:0.1727
# timer:  1.0178 sec.
# -------------
# Epoch 70/300
# -------------
# (train)
# -------------
# epoch 70 || Epoch_D_Loss:0.0871 ||Epoch_G_Loss:0.2178
# timer:  1.0511 sec.
# -------------
# Epoch 71/300
# -------------
# (train)
# -------------
# epoch 71 || Epoch_D_Loss:0.1057 ||Epoch_G_Loss:0.1691
# timer:  1.0166 sec.
# -------------
# Epoch 72/300
# -------------
# (train)
# -------------
# epoch 72 || Epoch_D_Loss:0.0737 ||Epoch_G_Loss:0.1822
# timer:  1.0140 sec.
# -------------
# Epoch 73/300
# -------------
# (train)
# -------------
# epoch 73 || Epoch_D_Loss:0.0920 ||Epoch_G_Loss:0.1996
# timer:  1.0128 sec.
# -------------
# Epoch 74/300
# -------------
# (train)
# -------------
# epoch 74 || Epoch_D_Loss:0.0973 ||Epoch_G_Loss:0.1906
# timer:  1.0186 sec.
# -------------
# Epoch 75/300
# -------------
# (train)
# -------------
# epoch 75 || Epoch_D_Loss:0.0876 ||Epoch_G_Loss:0.1889
# timer:  1.0156 sec.
# -------------
# Epoch 76/300
# -------------
# (train)
# -------------
# epoch 76 || Epoch_D_Loss:0.0904 ||Epoch_G_Loss:0.1923
# timer:  1.0053 sec.
# -------------
# Epoch 77/300
# -------------
# (train)
# -------------
# epoch 77 || Epoch_D_Loss:0.0839 ||Epoch_G_Loss:0.1986
# timer:  1.0149 sec.
# -------------
# Epoch 78/300
# -------------
# (train)
# -------------
# epoch 78 || Epoch_D_Loss:0.0798 ||Epoch_G_Loss:0.1877
# timer:  1.0305 sec.
# -------------
# Epoch 79/300
# -------------
# (train)
# -------------
# epoch 79 || Epoch_D_Loss:0.0692 ||Epoch_G_Loss:0.2211
# timer:  1.0164 sec.
# -------------
# Epoch 80/300
# -------------
# (train)
# -------------
# epoch 80 || Epoch_D_Loss:0.1108 ||Epoch_G_Loss:0.2081
# timer:  1.0205 sec.
# -------------
# Epoch 81/300
# -------------
# (train)
# -------------
# epoch 81 || Epoch_D_Loss:0.0678 ||Epoch_G_Loss:0.2435
# timer:  1.0249 sec.
# -------------
# Epoch 82/300
# -------------
# (train)
# -------------
# epoch 82 || Epoch_D_Loss:0.0990 ||Epoch_G_Loss:0.1663
# timer:  1.0161 sec.
# -------------
# Epoch 83/300
# -------------
# (train)
# -------------
# epoch 83 || Epoch_D_Loss:0.0843 ||Epoch_G_Loss:0.2080
# timer:  1.0181 sec.
# -------------
# Epoch 84/300
# -------------
# (train)
# -------------
# epoch 84 || Epoch_D_Loss:0.0847 ||Epoch_G_Loss:0.2034
# timer:  1.0246 sec.
# -------------
# Epoch 85/300
# -------------
# (train)
# -------------
# epoch 85 || Epoch_D_Loss:0.0782 ||Epoch_G_Loss:0.2051
# timer:  1.0406 sec.
# -------------
# Epoch 86/300
# -------------
# (train)
# -------------
# epoch 86 || Epoch_D_Loss:0.0915 ||Epoch_G_Loss:0.1993
# timer:  1.0350 sec.
# -------------
# Epoch 87/300
# -------------
# (train)
# -------------
# epoch 87 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.2020
# timer:  1.0362 sec.
# -------------
# Epoch 88/300
# -------------
# (train)
# -------------
# epoch 88 || Epoch_D_Loss:0.0710 ||Epoch_G_Loss:0.2177
# timer:  1.0217 sec.
# -------------
# Epoch 89/300
# -------------
# (train)
# -------------
# epoch 89 || Epoch_D_Loss:0.0822 ||Epoch_G_Loss:0.1926
# timer:  1.0389 sec.
# -------------
# Epoch 90/300
# -------------
# (train)
# -------------
# epoch 90 || Epoch_D_Loss:0.0791 ||Epoch_G_Loss:0.2137
# timer:  1.0216 sec.
# -------------
# Epoch 91/300
# -------------
# (train)
# -------------
# epoch 91 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:0.2734
# timer:  1.0291 sec.
# -------------
# Epoch 92/300
# -------------
# (train)
# -------------
# epoch 92 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1556
# timer:  1.0174 sec.
# -------------
# Epoch 93/300
# -------------
# (train)
# -------------
# epoch 93 || Epoch_D_Loss:0.0616 ||Epoch_G_Loss:0.2275
# timer:  1.0233 sec.
# -------------
# Epoch 94/300
# -------------
# (train)
# -------------
# epoch 94 || Epoch_D_Loss:0.0793 ||Epoch_G_Loss:0.2121
# timer:  1.0210 sec.
# -------------
# Epoch 95/300
# -------------
# (train)
# -------------
# epoch 95 || Epoch_D_Loss:0.1059 ||Epoch_G_Loss:0.2338
# timer:  1.0375 sec.
# -------------
# Epoch 96/300
# -------------
# (train)
# -------------
# epoch 96 || Epoch_D_Loss:0.0576 ||Epoch_G_Loss:0.2223
# timer:  1.0165 sec.
# -------------
# Epoch 97/300
# -------------
# (train)
# -------------
# epoch 97 || Epoch_D_Loss:0.0914 ||Epoch_G_Loss:0.2383
# timer:  1.0287 sec.
# -------------
# Epoch 98/300
# -------------
# (train)
# -------------
# epoch 98 || Epoch_D_Loss:0.0896 ||Epoch_G_Loss:0.2266
# timer:  1.0212 sec.
# -------------
# Epoch 99/300
# -------------
# (train)
# -------------
# epoch 99 || Epoch_D_Loss:0.0589 ||Epoch_G_Loss:0.2350
# timer:  1.0283 sec.
# -------------
# Epoch 100/300
# -------------
# (train)
# -------------
# epoch 100 || Epoch_D_Loss:0.0791 ||Epoch_G_Loss:0.2124
# timer:  1.0359 sec.
# -------------
# Epoch 101/300
# -------------
# (train)
# -------------
# epoch 101 || Epoch_D_Loss:0.0841 ||Epoch_G_Loss:0.2458
# timer:  1.0088 sec.
# -------------
# Epoch 102/300
# -------------
# (train)
# -------------
# epoch 102 || Epoch_D_Loss:0.0722 ||Epoch_G_Loss:0.2174
# timer:  1.0149 sec.
# -------------
# Epoch 103/300
# -------------
# (train)
# -------------
# epoch 103 || Epoch_D_Loss:0.0714 ||Epoch_G_Loss:0.1933
# timer:  1.0137 sec.
# -------------
# Epoch 104/300
# -------------
# (train)
# -------------
# epoch 104 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.2420
# timer:  1.0031 sec.
# -------------
# Epoch 105/300
# -------------
# (train)
# -------------
# epoch 105 || Epoch_D_Loss:0.0770 ||Epoch_G_Loss:0.2284
# timer:  1.0424 sec.
# -------------
# Epoch 106/300
# -------------
# (train)
# -------------
# epoch 106 || Epoch_D_Loss:0.0703 ||Epoch_G_Loss:0.2341
# timer:  1.0423 sec.
# -------------
# Epoch 107/300
# -------------
# (train)
# -------------
# epoch 107 || Epoch_D_Loss:0.0768 ||Epoch_G_Loss:0.2469
# timer:  1.0146 sec.
# -------------
# Epoch 108/300
# -------------
# (train)
# -------------
# epoch 108 || Epoch_D_Loss:0.0606 ||Epoch_G_Loss:0.2362
# timer:  1.0168 sec.
# -------------
# Epoch 109/300
# -------------
# (train)
# -------------
# epoch 109 || Epoch_D_Loss:0.0788 ||Epoch_G_Loss:0.2458
# timer:  1.0052 sec.
# -------------
# Epoch 110/300
# -------------
# (train)
# -------------
# epoch 110 || Epoch_D_Loss:0.0790 ||Epoch_G_Loss:0.2241
# timer:  1.0099 sec.
# -------------
# Epoch 111/300
# -------------
# (train)
# -------------
# epoch 111 || Epoch_D_Loss:0.0592 ||Epoch_G_Loss:0.2415
# timer:  1.0252 sec.
# -------------
# Epoch 112/300
# -------------
# (train)
# -------------
# epoch 112 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.2387
# timer:  1.0127 sec.
# -------------
# Epoch 113/300
# -------------
# (train)
# -------------
# epoch 113 || Epoch_D_Loss:0.0658 ||Epoch_G_Loss:0.2644
# timer:  1.0212 sec.
# -------------
# Epoch 114/300
# -------------
# (train)
# -------------
# epoch 114 || Epoch_D_Loss:0.0714 ||Epoch_G_Loss:0.2455
# timer:  1.0149 sec.
# -------------
# Epoch 115/300
# -------------
# (train)
# -------------
# epoch 115 || Epoch_D_Loss:0.0709 ||Epoch_G_Loss:0.2350
# timer:  1.0515 sec.
# -------------
# Epoch 116/300
# -------------
# (train)
# -------------
# epoch 116 || Epoch_D_Loss:0.0805 ||Epoch_G_Loss:0.2687
# timer:  0.9944 sec.
# -------------
# Epoch 117/300
# -------------
# (train)
# -------------
# epoch 117 || Epoch_D_Loss:0.0535 ||Epoch_G_Loss:0.2632
# timer:  1.0119 sec.
# -------------
# Epoch 118/300
# -------------
# (train)
# -------------
# epoch 118 || Epoch_D_Loss:0.0633 ||Epoch_G_Loss:0.2245
# timer:  1.0171 sec.
# -------------
# Epoch 119/300
# -------------
# (train)
# -------------
# epoch 119 || Epoch_D_Loss:0.0847 ||Epoch_G_Loss:0.2496
# timer:  1.0152 sec.
# -------------
# Epoch 120/300
# -------------
# (train)
# -------------
# epoch 120 || Epoch_D_Loss:0.0727 ||Epoch_G_Loss:0.2554
# timer:  1.0224 sec.
# -------------
# Epoch 121/300
# -------------
# (train)
# -------------
# epoch 121 || Epoch_D_Loss:0.0600 ||Epoch_G_Loss:0.2683
# timer:  1.0106 sec.
# -------------
# Epoch 122/300
# -------------
# (train)
# -------------
# epoch 122 || Epoch_D_Loss:0.0696 ||Epoch_G_Loss:0.2676
# timer:  1.0268 sec.
# -------------
# Epoch 123/300
# -------------
# (train)
# -------------
# epoch 123 || Epoch_D_Loss:0.0692 ||Epoch_G_Loss:0.2567
# timer:  1.0128 sec.
# -------------
# Epoch 124/300
# -------------
# (train)
# -------------
# epoch 124 || Epoch_D_Loss:0.0609 ||Epoch_G_Loss:0.2734
# timer:  1.0470 sec.
# -------------
# Epoch 125/300
# -------------
# (train)
# -------------
# epoch 125 || Epoch_D_Loss:0.0576 ||Epoch_G_Loss:0.3012
# timer:  1.0184 sec.
# -------------
# Epoch 126/300
# -------------
# (train)
# -------------
# epoch 126 || Epoch_D_Loss:0.0704 ||Epoch_G_Loss:0.2638
# timer:  1.0141 sec.
# -------------
# Epoch 127/300
# -------------
# (train)
# -------------
# epoch 127 || Epoch_D_Loss:0.0559 ||Epoch_G_Loss:0.2864
# timer:  1.0160 sec.
# -------------
# Epoch 128/300
# -------------
# (train)
# -------------
# epoch 128 || Epoch_D_Loss:0.0650 ||Epoch_G_Loss:0.2618
# timer:  1.0147 sec.
# -------------
# Epoch 129/300
# -------------
# (train)
# -------------
# epoch 129 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:0.2676
# timer:  1.0170 sec.
# -------------
# Epoch 130/300
# -------------
# (train)
# -------------
# epoch 130 || Epoch_D_Loss:0.0660 ||Epoch_G_Loss:0.2753
# timer:  1.0424 sec.
# -------------
# Epoch 131/300
# -------------
# (train)
# -------------
# epoch 131 || Epoch_D_Loss:0.0623 ||Epoch_G_Loss:0.2877
# timer:  1.0487 sec.
# -------------
# Epoch 132/300
# -------------
# (train)
# -------------
# epoch 132 || Epoch_D_Loss:0.0683 ||Epoch_G_Loss:0.3078
# timer:  1.0567 sec.
# -------------
# Epoch 133/300
# -------------
# (train)
# -------------
# epoch 133 || Epoch_D_Loss:0.0700 ||Epoch_G_Loss:0.2471
# timer:  1.0740 sec.
# -------------
# Epoch 134/300
# -------------
# (train)
# -------------
# epoch 134 || Epoch_D_Loss:0.0382 ||Epoch_G_Loss:0.2963
# timer:  1.0595 sec.
# -------------
# Epoch 135/300
# -------------
# (train)
# -------------
# epoch 135 || Epoch_D_Loss:0.0799 ||Epoch_G_Loss:0.2755
# timer:  1.0607 sec.
# -------------
# Epoch 136/300
# -------------
# (train)
# -------------
# epoch 136 || Epoch_D_Loss:0.0668 ||Epoch_G_Loss:0.2761
# timer:  1.0088 sec.
# -------------
# Epoch 137/300
# -------------
# (train)
# -------------
# epoch 137 || Epoch_D_Loss:0.0478 ||Epoch_G_Loss:0.2869
# timer:  1.0192 sec.
# -------------
# Epoch 138/300
# -------------
# (train)
# -------------
# epoch 138 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.2837
# timer:  1.0217 sec.
# -------------
# Epoch 139/300
# -------------
# (train)
# -------------
# epoch 139 || Epoch_D_Loss:0.0571 ||Epoch_G_Loss:0.3217
# timer:  1.0184 sec.
# -------------
# Epoch 140/300
# -------------
# (train)
# -------------
# epoch 140 || Epoch_D_Loss:0.0549 ||Epoch_G_Loss:0.2776
# timer:  1.0108 sec.
# -------------
# Epoch 141/300
# -------------
# (train)
# -------------
# epoch 141 || Epoch_D_Loss:0.0660 ||Epoch_G_Loss:0.2814
# timer:  1.0157 sec.
# -------------
# Epoch 142/300
# -------------
# (train)
# -------------
# epoch 142 || Epoch_D_Loss:0.0328 ||Epoch_G_Loss:0.3439
# timer:  1.0100 sec.
# -------------
# Epoch 143/300
# -------------
# (train)
# -------------
# epoch 143 || Epoch_D_Loss:0.0761 ||Epoch_G_Loss:0.2933
# timer:  1.0172 sec.
# -------------
# Epoch 144/300
# -------------
# (train)
# -------------
# epoch 144 || Epoch_D_Loss:0.0674 ||Epoch_G_Loss:0.2782
# timer:  1.0290 sec.
# -------------
# Epoch 145/300
# -------------
# (train)
# -------------
# epoch 145 || Epoch_D_Loss:0.0520 ||Epoch_G_Loss:0.3227
# timer:  1.0248 sec.
# -------------
# Epoch 146/300
# -------------
# (train)
# -------------
# epoch 146 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.3057
# timer:  1.0107 sec.
# -------------
# Epoch 147/300
# -------------
# (train)
# -------------
# epoch 147 || Epoch_D_Loss:0.0441 ||Epoch_G_Loss:0.3419
# timer:  1.0202 sec.
# -------------
# Epoch 148/300
# -------------
# (train)
# -------------
# epoch 148 || Epoch_D_Loss:0.0645 ||Epoch_G_Loss:0.2917
# timer:  1.0130 sec.
# -------------
# Epoch 149/300
# -------------
# (train)
# -------------
# epoch 149 || Epoch_D_Loss:0.0494 ||Epoch_G_Loss:0.2912
# timer:  1.0145 sec.
# -------------
# Epoch 150/300
# -------------
# (train)
# -------------
# epoch 150 || Epoch_D_Loss:0.0478 ||Epoch_G_Loss:0.3024
# timer:  1.0056 sec.
# -------------
# Epoch 151/300
# -------------
# (train)
# -------------
# epoch 151 || Epoch_D_Loss:0.0561 ||Epoch_G_Loss:0.3132
# timer:  1.0241 sec.
# -------------
# Epoch 152/300
# -------------
# (train)
# -------------
# epoch 152 || Epoch_D_Loss:0.0513 ||Epoch_G_Loss:0.3465
# timer:  1.0069 sec.
# -------------
# Epoch 153/300
# -------------
# (train)
# -------------
# epoch 153 || Epoch_D_Loss:0.0551 ||Epoch_G_Loss:0.3009
# timer:  1.0245 sec.
# -------------
# Epoch 154/300
# -------------
# (train)
# -------------
# epoch 154 || Epoch_D_Loss:0.0450 ||Epoch_G_Loss:0.3510
# timer:  1.0335 sec.
# -------------
# Epoch 155/300
# -------------
# (train)
# -------------
# epoch 155 || Epoch_D_Loss:0.0645 ||Epoch_G_Loss:0.3030
# timer:  1.0263 sec.
# -------------
# Epoch 156/300
# -------------
# (train)
# -------------
# epoch 156 || Epoch_D_Loss:0.0358 ||Epoch_G_Loss:0.3419
# timer:  1.0150 sec.
# -------------
# Epoch 157/300
# -------------
# (train)
# -------------
# epoch 157 || Epoch_D_Loss:0.0530 ||Epoch_G_Loss:0.3395
# timer:  1.0214 sec.
# -------------
# Epoch 158/300
# -------------
# (train)
# -------------
# epoch 158 || Epoch_D_Loss:0.0511 ||Epoch_G_Loss:0.3231
# timer:  1.0349 sec.
# -------------
# Epoch 159/300
# -------------
# (train)
# -------------
# epoch 159 || Epoch_D_Loss:0.0453 ||Epoch_G_Loss:0.3365
# timer:  1.0148 sec.
# -------------
# Epoch 160/300
# -------------
# (train)
# -------------
# epoch 160 || Epoch_D_Loss:0.0436 ||Epoch_G_Loss:0.3575
# timer:  1.0428 sec.
# -------------
# Epoch 161/300
# -------------
# (train)
# -------------
# epoch 161 || Epoch_D_Loss:0.0512 ||Epoch_G_Loss:0.3745
# timer:  1.0217 sec.
# -------------
# Epoch 162/300
# -------------
# (train)
# -------------
# epoch 162 || Epoch_D_Loss:0.0576 ||Epoch_G_Loss:0.2831
# timer:  1.0012 sec.
# -------------
# Epoch 163/300
# -------------
# (train)
# -------------
# epoch 163 || Epoch_D_Loss:0.0518 ||Epoch_G_Loss:0.3461
# timer:  1.0057 sec.
# -------------
# Epoch 164/300
# -------------
# (train)
# -------------
# epoch 164 || Epoch_D_Loss:0.0483 ||Epoch_G_Loss:0.3573
# timer:  1.0462 sec.
# -------------
# Epoch 165/300
# -------------
# (train)
# -------------
# epoch 165 || Epoch_D_Loss:0.0320 ||Epoch_G_Loss:0.3810
# timer:  1.0104 sec.
# -------------
# Epoch 166/300
# -------------
# (train)
# -------------
# epoch 166 || Epoch_D_Loss:0.0491 ||Epoch_G_Loss:0.3681
# timer:  1.0144 sec.
# -------------
# Epoch 167/300
# -------------
# (train)
# -------------
# epoch 167 || Epoch_D_Loss:0.0563 ||Epoch_G_Loss:0.3568
# timer:  1.0210 sec.
# -------------
# Epoch 168/300
# -------------
# (train)
# -------------
# epoch 168 || Epoch_D_Loss:0.0522 ||Epoch_G_Loss:0.3624
# timer:  1.0129 sec.
# -------------
# Epoch 169/300
# -------------
# (train)
# -------------
# epoch 169 || Epoch_D_Loss:0.0400 ||Epoch_G_Loss:0.3587
# timer:  1.0093 sec.
# -------------
# Epoch 170/300
# -------------
# (train)
# -------------
# epoch 170 || Epoch_D_Loss:0.0425 ||Epoch_G_Loss:0.3736
# timer:  1.0085 sec.
# -------------
# Epoch 171/300
# -------------
# (train)
# -------------
# epoch 171 || Epoch_D_Loss:0.0349 ||Epoch_G_Loss:0.4167
# timer:  1.0101 sec.
# -------------
# Epoch 172/300
# -------------
# (train)
# -------------
# epoch 172 || Epoch_D_Loss:0.0568 ||Epoch_G_Loss:0.3128
# timer:  1.0139 sec.
# -------------
# Epoch 173/300
# -------------
# (train)
# -------------
# epoch 173 || Epoch_D_Loss:0.0410 ||Epoch_G_Loss:0.4164
# timer:  1.0108 sec.
# -------------
# Epoch 174/300
# -------------
# (train)
# -------------
# epoch 174 || Epoch_D_Loss:0.0392 ||Epoch_G_Loss:0.3381
# timer:  1.0104 sec.
# -------------
# Epoch 175/300
# -------------
# (train)
# -------------
# epoch 175 || Epoch_D_Loss:0.0534 ||Epoch_G_Loss:0.3730
# timer:  1.0162 sec.
# -------------
# Epoch 176/300
# -------------
# (train)
# -------------
# epoch 176 || Epoch_D_Loss:0.0229 ||Epoch_G_Loss:0.4549
# timer:  1.0296 sec.
# -------------
# Epoch 177/300
# -------------
# (train)
# -------------
# epoch 177 || Epoch_D_Loss:0.0673 ||Epoch_G_Loss:0.3421
# timer:  1.0245 sec.
# -------------
# Epoch 178/300
# -------------
# (train)
# -------------
# epoch 178 || Epoch_D_Loss:0.0380 ||Epoch_G_Loss:0.3884
# timer:  1.0077 sec.
# -------------
# Epoch 179/300
# -------------
# (train)
# -------------
# epoch 179 || Epoch_D_Loss:0.0333 ||Epoch_G_Loss:0.3918
# timer:  1.0170 sec.
# -------------
# Epoch 180/300
# -------------
# (train)
# -------------
# epoch 180 || Epoch_D_Loss:0.0601 ||Epoch_G_Loss:0.3248
# timer:  0.9969 sec.
# -------------
# Epoch 181/300
# -------------
# (train)
# -------------
# epoch 181 || Epoch_D_Loss:0.0416 ||Epoch_G_Loss:0.4049
# timer:  1.0210 sec.
# -------------
# Epoch 182/300
# -------------
# (train)
# -------------
# epoch 182 || Epoch_D_Loss:0.0399 ||Epoch_G_Loss:0.4104
# timer:  1.0261 sec.
# -------------
# Epoch 183/300
# -------------
# (train)
# -------------
# epoch 183 || Epoch_D_Loss:0.0197 ||Epoch_G_Loss:0.4343
# timer:  1.0314 sec.
# -------------
# Epoch 184/300
# -------------
# (train)
# -------------
# epoch 184 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.4137
# timer:  1.0161 sec.
# -------------
# Epoch 185/300
# -------------
# (train)
# -------------
# epoch 185 || Epoch_D_Loss:0.0342 ||Epoch_G_Loss:0.4196
# timer:  1.0177 sec.
# -------------
# Epoch 186/300
# -------------
# (train)
# -------------
# epoch 186 || Epoch_D_Loss:0.0301 ||Epoch_G_Loss:0.4181
# timer:  1.0200 sec.
# -------------
# Epoch 187/300
# -------------
# (train)
# -------------
# epoch 187 || Epoch_D_Loss:0.0519 ||Epoch_G_Loss:0.3983
# timer:  1.0257 sec.
# -------------
# Epoch 188/300
# -------------
# (train)
# -------------
# epoch 188 || Epoch_D_Loss:0.0412 ||Epoch_G_Loss:0.4115
# timer:  1.0152 sec.
# -------------
# Epoch 189/300
# -------------
# (train)
# -------------
# epoch 189 || Epoch_D_Loss:0.0151 ||Epoch_G_Loss:0.4511
# timer:  1.0490 sec.
# -------------
# Epoch 190/300
# -------------
# (train)
# -------------
# epoch 190 || Epoch_D_Loss:0.0433 ||Epoch_G_Loss:0.4101
# timer:  1.0431 sec.
# -------------
# Epoch 191/300
# -------------
# (train)
# -------------
# epoch 191 || Epoch_D_Loss:0.0451 ||Epoch_G_Loss:0.4167
# timer:  1.0101 sec.
# -------------
# Epoch 192/300
# -------------
# (train)
# -------------
# epoch 192 || Epoch_D_Loss:0.0254 ||Epoch_G_Loss:0.4521
# timer:  1.0159 sec.
# -------------
# Epoch 193/300
# -------------
# (train)
# -------------
# epoch 193 || Epoch_D_Loss:0.0535 ||Epoch_G_Loss:0.3904
# timer:  0.9985 sec.
# -------------
# Epoch 194/300
# -------------
# (train)
# -------------
# epoch 194 || Epoch_D_Loss:0.0173 ||Epoch_G_Loss:0.4654
# timer:  1.0212 sec.
# -------------
# Epoch 195/300
# -------------
# (train)
# -------------
# epoch 195 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.4111
# timer:  1.0219 sec.
# -------------
# Epoch 196/300
# -------------
# (train)
# -------------
# epoch 196 || Epoch_D_Loss:0.0281 ||Epoch_G_Loss:0.4157
# timer:  1.0137 sec.
# -------------
# Epoch 197/300
# -------------
# (train)
# -------------
# epoch 197 || Epoch_D_Loss:0.0400 ||Epoch_G_Loss:0.3961
# timer:  1.0247 sec.
# -------------
# Epoch 198/300
# -------------
# (train)
# -------------
# epoch 198 || Epoch_D_Loss:0.0206 ||Epoch_G_Loss:0.4374
# timer:  1.0149 sec.
# -------------
# Epoch 199/300
# -------------
# (train)
# -------------
# epoch 199 || Epoch_D_Loss:0.0470 ||Epoch_G_Loss:0.4519
# timer:  1.0338 sec.
# -------------
# Epoch 200/300
# -------------
# (train)
# -------------
# epoch 200 || Epoch_D_Loss:0.0204 ||Epoch_G_Loss:0.4726
# timer:  1.0068 sec.
# -------------
# Epoch 201/300
# -------------
# (train)
# -------------
# epoch 201 || Epoch_D_Loss:0.0103 ||Epoch_G_Loss:0.5017
# timer:  1.0063 sec.
# -------------
# Epoch 202/300
# -------------
# (train)
# -------------
# epoch 202 || Epoch_D_Loss:0.0733 ||Epoch_G_Loss:0.4320
# timer:  1.0199 sec.
# -------------
# Epoch 203/300
# -------------
# (train)
# -------------
# epoch 203 || Epoch_D_Loss:0.0161 ||Epoch_G_Loss:0.4053
# timer:  1.0143 sec.
# -------------
# Epoch 204/300
# -------------
# (train)
# -------------
# epoch 204 || Epoch_D_Loss:0.0558 ||Epoch_G_Loss:0.4082
# timer:  1.0170 sec.
# -------------
# Epoch 205/300
# -------------
# (train)
# -------------
# epoch 205 || Epoch_D_Loss:0.0166 ||Epoch_G_Loss:0.4703
# timer:  1.0081 sec.
# -------------
# Epoch 206/300
# -------------
# (train)
# -------------
# epoch 206 || Epoch_D_Loss:0.0388 ||Epoch_G_Loss:0.4701
# timer:  1.0033 sec.
# -------------
# Epoch 207/300
# -------------
# (train)
# -------------
# epoch 207 || Epoch_D_Loss:0.0382 ||Epoch_G_Loss:0.4067
# timer:  1.0138 sec.
# -------------
# Epoch 208/300
# -------------
# (train)
# -------------
# epoch 208 || Epoch_D_Loss:0.0285 ||Epoch_G_Loss:0.5698
# timer:  1.0316 sec.
# -------------
# Epoch 209/300
# -------------
# (train)
# -------------
# epoch 209 || Epoch_D_Loss:0.0361 ||Epoch_G_Loss:0.3923
# timer:  1.0191 sec.
# -------------
# Epoch 210/300
# -------------
# (train)
# -------------
# epoch 210 || Epoch_D_Loss:0.0107 ||Epoch_G_Loss:0.5336
# timer:  1.0084 sec.
# -------------
# Epoch 211/300
# -------------
# (train)
# -------------
# epoch 211 || Epoch_D_Loss:0.0409 ||Epoch_G_Loss:0.4604
# timer:  1.0302 sec.
# -------------
# Epoch 212/300
# -------------
# (train)
# -------------
# epoch 212 || Epoch_D_Loss:0.0158 ||Epoch_G_Loss:0.5601
# timer:  1.0271 sec.
# -------------
# Epoch 213/300
# -------------
# (train)
# -------------
# epoch 213 || Epoch_D_Loss:0.0505 ||Epoch_G_Loss:0.3817
# timer:  1.0257 sec.
# -------------
# Epoch 214/300
# -------------
# (train)
# -------------
# epoch 214 || Epoch_D_Loss:0.0208 ||Epoch_G_Loss:0.4938
# timer:  1.0077 sec.
# -------------
# Epoch 215/300
# -------------
# (train)
# -------------
# epoch 215 || Epoch_D_Loss:0.0367 ||Epoch_G_Loss:0.5047
# timer:  1.0149 sec.
# -------------
# Epoch 216/300
# -------------
# (train)
# -------------
# epoch 216 || Epoch_D_Loss:0.0157 ||Epoch_G_Loss:0.5146
# timer:  1.0138 sec.
# -------------
# Epoch 217/300
# -------------
# (train)
# -------------
# epoch 217 || Epoch_D_Loss:0.0317 ||Epoch_G_Loss:0.3997
# timer:  1.0242 sec.
# -------------
# Epoch 218/300
# -------------
# (train)
# -------------
# epoch 218 || Epoch_D_Loss:0.0311 ||Epoch_G_Loss:0.4769
# timer:  1.0148 sec.
# -------------
# Epoch 219/300
# -------------
# (train)
# -------------
# epoch 219 || Epoch_D_Loss:0.0209 ||Epoch_G_Loss:0.5489
# timer:  1.0089 sec.
# -------------
# Epoch 220/300
# -------------
# (train)
# -------------
# epoch 220 || Epoch_D_Loss:0.0288 ||Epoch_G_Loss:0.5091
# timer:  1.0070 sec.
# -------------
# Epoch 221/300
# -------------
# (train)
# -------------
# epoch 221 || Epoch_D_Loss:0.0240 ||Epoch_G_Loss:0.5647
# timer:  1.0256 sec.
# -------------
# Epoch 222/300
# -------------
# (train)
# -------------
# epoch 222 || Epoch_D_Loss:0.0339 ||Epoch_G_Loss:0.4672
# timer:  1.0132 sec.
# -------------
# Epoch 223/300
# -------------
# (train)
# -------------
# epoch 223 || Epoch_D_Loss:0.0124 ||Epoch_G_Loss:0.5597
# timer:  0.9976 sec.
# -------------
# Epoch 224/300
# -------------
# (train)
# -------------
# epoch 224 || Epoch_D_Loss:0.0492 ||Epoch_G_Loss:0.4381
# timer:  1.0258 sec.
# -------------
# Epoch 225/300
# -------------
# (train)
# -------------
# epoch 225 || Epoch_D_Loss:0.0172 ||Epoch_G_Loss:0.5189
# timer:  1.0409 sec.
# -------------
# Epoch 226/300
# -------------
# (train)
# -------------
# epoch 226 || Epoch_D_Loss:0.0347 ||Epoch_G_Loss:0.5329
# timer:  1.0425 sec.
# -------------
# Epoch 227/300
# -------------
# (train)
# -------------
# epoch 227 || Epoch_D_Loss:0.0182 ||Epoch_G_Loss:0.5387
# timer:  1.0389 sec.
# -------------
# Epoch 228/300
# -------------
# (train)
# -------------
# epoch 228 || Epoch_D_Loss:0.0419 ||Epoch_G_Loss:0.5107
# timer:  1.0262 sec.
# -------------
# Epoch 229/300
# -------------
# (train)
# -------------
# epoch 229 || Epoch_D_Loss:0.0173 ||Epoch_G_Loss:0.4982
# timer:  1.0244 sec.
# -------------
# Epoch 230/300
# -------------
# (train)
# -------------
# epoch 230 || Epoch_D_Loss:0.0145 ||Epoch_G_Loss:0.6101
# timer:  1.0204 sec.
# -------------
# Epoch 231/300
# -------------
# (train)
# -------------
# epoch 231 || Epoch_D_Loss:0.0419 ||Epoch_G_Loss:0.5423
# timer:  1.0335 sec.
# -------------
# Epoch 232/300
# -------------
# (train)
# -------------
# epoch 232 || Epoch_D_Loss:0.0163 ||Epoch_G_Loss:0.5801
# timer:  1.0453 sec.
# -------------
# Epoch 233/300
# -------------
# (train)
# -------------
# epoch 233 || Epoch_D_Loss:0.0065 ||Epoch_G_Loss:0.6025
# timer:  1.0566 sec.
# -------------
# Epoch 234/300
# -------------
# (train)
# -------------
# epoch 234 || Epoch_D_Loss:0.0476 ||Epoch_G_Loss:0.5025
# timer:  1.0485 sec.
# -------------
# Epoch 235/300
# -------------
# (train)
# -------------
# epoch 235 || Epoch_D_Loss:0.0242 ||Epoch_G_Loss:0.5255
# timer:  1.0292 sec.
# -------------
# Epoch 236/300
# -------------
# (train)
# -------------
# epoch 236 || Epoch_D_Loss:0.0164 ||Epoch_G_Loss:0.5555
# timer:  1.0264 sec.
# -------------
# Epoch 237/300
# -------------
# (train)
# -------------
# epoch 237 || Epoch_D_Loss:0.0264 ||Epoch_G_Loss:0.5911
# timer:  1.0206 sec.
# -------------
# Epoch 238/300
# -------------
# (train)
# -------------
# epoch 238 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.4666
# timer:  1.0310 sec.
# -------------
# Epoch 239/300
# -------------
# (train)
# -------------
# epoch 239 || Epoch_D_Loss:0.0226 ||Epoch_G_Loss:0.6023
# timer:  1.0335 sec.
# -------------
# Epoch 240/300
# -------------
# (train)
# -------------
# epoch 240 || Epoch_D_Loss:0.0116 ||Epoch_G_Loss:0.5709
# timer:  1.0106 sec.
# -------------
# Epoch 241/300
# -------------
# (train)
# -------------
# epoch 241 || Epoch_D_Loss:0.0411 ||Epoch_G_Loss:0.6059
# timer:  1.0203 sec.
# -------------
# Epoch 242/300
# -------------
# (train)
# -------------
# epoch 242 || Epoch_D_Loss:0.0260 ||Epoch_G_Loss:0.4822
# timer:  1.0360 sec.
# -------------
# Epoch 243/300
# -------------
# (train)
# -------------
# epoch 243 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.5982
# timer:  1.0318 sec.
# -------------
# Epoch 244/300
# -------------
# (train)
# -------------
# epoch 244 || Epoch_D_Loss:0.0529 ||Epoch_G_Loss:0.5531
# timer:  1.0374 sec.
# -------------
# Epoch 245/300
# -------------
# (train)
# -------------
# epoch 245 || Epoch_D_Loss:0.0139 ||Epoch_G_Loss:0.5351
# timer:  1.0139 sec.
# -------------
# Epoch 246/300
# -------------
# (train)
# -------------
# epoch 246 || Epoch_D_Loss:0.0166 ||Epoch_G_Loss:0.6328
# timer:  1.0124 sec.
# -------------
# Epoch 247/300
# -------------
# (train)
# -------------
# epoch 247 || Epoch_D_Loss:0.0584 ||Epoch_G_Loss:0.4336
# timer:  1.0354 sec.
# -------------
# Epoch 248/300
# -------------
# (train)
# -------------
# epoch 248 || Epoch_D_Loss:0.0175 ||Epoch_G_Loss:0.5516
# timer:  1.0415 sec.
# -------------
# Epoch 249/300
# -------------
# (train)
# -------------
# epoch 249 || Epoch_D_Loss:0.0080 ||Epoch_G_Loss:0.6027
# timer:  1.0007 sec.
# -------------
# Epoch 250/300
# -------------
# (train)
# -------------
# epoch 250 || Epoch_D_Loss:0.0257 ||Epoch_G_Loss:0.6117
# timer:  1.0140 sec.
# -------------
# Epoch 251/300
# -------------
# (train)
# -------------
# epoch 251 || Epoch_D_Loss:0.0266 ||Epoch_G_Loss:0.5248
# timer:  1.0059 sec.
# -------------
# Epoch 252/300
# -------------
# (train)
# -------------
# epoch 252 || Epoch_D_Loss:0.0239 ||Epoch_G_Loss:0.6060
# timer:  1.0090 sec.
# -------------
# Epoch 253/300
# -------------
# (train)
# -------------
# epoch 253 || Epoch_D_Loss:0.0052 ||Epoch_G_Loss:0.6706
# timer:  0.9959 sec.
# -------------
# Epoch 254/300
# -------------
# (train)
# -------------
# epoch 254 || Epoch_D_Loss:0.0588 ||Epoch_G_Loss:0.5104
# timer:  1.0110 sec.
# -------------
# Epoch 255/300
# -------------
# (train)
# -------------
# epoch 255 || Epoch_D_Loss:0.0069 ||Epoch_G_Loss:0.6319
# timer:  1.0173 sec.
# -------------
# Epoch 256/300
# -------------
# (train)
# -------------
# epoch 256 || Epoch_D_Loss:0.0057 ||Epoch_G_Loss:0.6363
# timer:  1.0169 sec.
# -------------
# Epoch 257/300
# -------------
# (train)
# -------------
# epoch 257 || Epoch_D_Loss:0.0435 ||Epoch_G_Loss:0.5840
# timer:  1.0475 sec.
# -------------
# Epoch 258/300
# -------------
# (train)
# -------------
# epoch 258 || Epoch_D_Loss:0.0116 ||Epoch_G_Loss:0.5028
# timer:  1.0232 sec.
# -------------
# Epoch 259/300
# -------------
# (train)
# -------------
# epoch 259 || Epoch_D_Loss:0.0089 ||Epoch_G_Loss:0.6350
# timer:  1.0090 sec.
# -------------
# Epoch 260/300
# -------------
# (train)
# -------------
# epoch 260 || Epoch_D_Loss:0.0433 ||Epoch_G_Loss:0.5867
# timer:  1.0169 sec.
# -------------
# Epoch 261/300
# -------------
# (train)
# -------------
# epoch 261 || Epoch_D_Loss:0.0122 ||Epoch_G_Loss:0.5877
# timer:  1.0168 sec.
# -------------
# Epoch 262/300
# -------------
# (train)
# -------------
# epoch 262 || Epoch_D_Loss:0.0082 ||Epoch_G_Loss:0.6876
# timer:  1.0152 sec.
# -------------
# Epoch 263/300
# -------------
# (train)
# -------------
# epoch 263 || Epoch_D_Loss:0.0292 ||Epoch_G_Loss:0.6422
# timer:  1.0127 sec.
# -------------
# Epoch 264/300
# -------------
# (train)
# -------------
# epoch 264 || Epoch_D_Loss:0.0267 ||Epoch_G_Loss:0.5247
# timer:  1.0185 sec.
# -------------
# Epoch 265/300
# -------------
# (train)
# -------------
# epoch 265 || Epoch_D_Loss:0.0080 ||Epoch_G_Loss:0.6495
# timer:  1.0155 sec.
# -------------
# Epoch 266/300
# -------------
# (train)
# -------------
# epoch 266 || Epoch_D_Loss:0.0188 ||Epoch_G_Loss:0.6645
# timer:  1.0149 sec.
# -------------
# Epoch 267/300
# -------------
# (train)
# -------------
# epoch 267 || Epoch_D_Loss:0.0037 ||Epoch_G_Loss:0.7240
# timer:  1.0232 sec.
# -------------
# Epoch 268/300
# -------------
# (train)
# -------------
# epoch 268 || Epoch_D_Loss:0.0400 ||Epoch_G_Loss:0.6217
# timer:  1.0228 sec.
# -------------
# Epoch 269/300
# -------------
# (train)
# -------------
# epoch 269 || Epoch_D_Loss:0.0124 ||Epoch_G_Loss:0.5754
# timer:  1.0162 sec.
# -------------
# Epoch 270/300
# -------------
# (train)
# -------------
# epoch 270 || Epoch_D_Loss:0.0180 ||Epoch_G_Loss:0.6421
# timer:  1.0144 sec.
# -------------
# Epoch 271/300
# -------------
# (train)
# -------------
# epoch 271 || Epoch_D_Loss:0.0091 ||Epoch_G_Loss:0.6650
# timer:  1.0136 sec.
# -------------
# Epoch 272/300
# -------------
# (train)
# -------------
# epoch 272 || Epoch_D_Loss:0.0086 ||Epoch_G_Loss:0.6688
# timer:  1.0224 sec.
# -------------
# Epoch 273/300
# -------------
# (train)
# -------------
# epoch 273 || Epoch_D_Loss:0.0587 ||Epoch_G_Loss:0.6425
# timer:  0.9988 sec.
# -------------
# Epoch 274/300
# -------------
# (train)
# -------------
# epoch 274 || Epoch_D_Loss:0.0159 ||Epoch_G_Loss:0.5276
# timer:  1.0126 sec.
# -------------
# Epoch 275/300
# -------------
# (train)
# -------------
# epoch 275 || Epoch_D_Loss:0.0056 ||Epoch_G_Loss:0.6682
# timer:  1.0212 sec.
# -------------
# Epoch 276/300
# -------------
# (train)
# -------------
# epoch 276 || Epoch_D_Loss:0.0035 ||Epoch_G_Loss:0.7134
# timer:  1.0136 sec.
# -------------
# Epoch 277/300
# -------------
# (train)
# -------------
# epoch 277 || Epoch_D_Loss:0.0501 ||Epoch_G_Loss:0.5783
# timer:  1.0240 sec.
# -------------
# Epoch 278/300
# -------------
# (train)
# -------------
# epoch 278 || Epoch_D_Loss:0.0072 ||Epoch_G_Loss:0.6340
# timer:  1.0169 sec.
# -------------
# Epoch 279/300
# -------------
# (train)
# -------------
# epoch 279 || Epoch_D_Loss:0.0092 ||Epoch_G_Loss:0.7323
# timer:  1.0206 sec.
# -------------
# Epoch 280/300
# -------------
# (train)
# -------------
# epoch 280 || Epoch_D_Loss:0.0490 ||Epoch_G_Loss:0.4879
# timer:  1.0086 sec.
# -------------
# Epoch 281/300
# -------------
# (train)
# -------------
# epoch 281 || Epoch_D_Loss:0.0083 ||Epoch_G_Loss:0.6449
# timer:  1.0279 sec.
# -------------
# Epoch 282/300
# -------------
# (train)
# -------------
# epoch 282 || Epoch_D_Loss:0.0045 ||Epoch_G_Loss:0.7273
# timer:  1.0078 sec.
# -------------
# Epoch 283/300
# -------------
# (train)
# -------------
# epoch 283 || Epoch_D_Loss:0.0260 ||Epoch_G_Loss:0.6835
# timer:  1.0273 sec.
# -------------
# Epoch 284/300
# -------------
# (train)
# -------------
# epoch 284 || Epoch_D_Loss:0.0070 ||Epoch_G_Loss:0.6920
# timer:  1.0272 sec.
# -------------
# Epoch 285/300
# -------------
# (train)
# -------------
# epoch 285 || Epoch_D_Loss:0.0159 ||Epoch_G_Loss:0.6693
# timer:  1.0146 sec.
# -------------
# Epoch 286/300
# -------------
# (train)
# -------------
# epoch 286 || Epoch_D_Loss:0.0386 ||Epoch_G_Loss:0.5975
# timer:  1.0210 sec.
# -------------
# Epoch 287/300
# -------------
# (train)
# -------------
# epoch 287 || Epoch_D_Loss:0.0089 ||Epoch_G_Loss:0.6146
# timer:  1.0192 sec.
# -------------
# Epoch 288/300
# -------------
# (train)
# -------------
# epoch 288 || Epoch_D_Loss:0.0328 ||Epoch_G_Loss:0.6477
# timer:  1.0101 sec.
# -------------
# Epoch 289/300
# -------------
# (train)
# -------------
# epoch 289 || Epoch_D_Loss:0.0127 ||Epoch_G_Loss:0.6176
# timer:  1.0359 sec.
# -------------
# Epoch 290/300
# -------------
# (train)
# -------------
# epoch 290 || Epoch_D_Loss:0.0038 ||Epoch_G_Loss:0.7394
# timer:  1.0849 sec.
# -------------
# Epoch 291/300
# -------------
# (train)
# -------------
# epoch 291 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.7773
# timer:  1.0549 sec.
# -------------
# Epoch 292/300
# -------------
# (train)
# -------------
# epoch 292 || Epoch_D_Loss:0.0431 ||Epoch_G_Loss:0.6290
# timer:  1.0176 sec.
# -------------
# Epoch 293/300
# -------------
# (train)
# -------------
# epoch 293 || Epoch_D_Loss:0.0116 ||Epoch_G_Loss:0.6318
# timer:  1.0134 sec.
# -------------
# Epoch 294/300
# -------------
# (train)
# -------------
# epoch 294 || Epoch_D_Loss:0.0053 ||Epoch_G_Loss:0.7237
# timer:  1.0118 sec.
# -------------
# Epoch 295/300
# -------------
# (train)
# -------------
# epoch 295 || Epoch_D_Loss:0.0023 ||Epoch_G_Loss:0.8277
# timer:  1.0086 sec.
# -------------
# Epoch 296/300
# -------------
# (train)
# -------------
# epoch 296 || Epoch_D_Loss:0.0490 ||Epoch_G_Loss:0.5629
# timer:  0.9955 sec.
# -------------
# Epoch 297/300
# -------------
# (train)
# -------------
# epoch 297 || Epoch_D_Loss:0.0140 ||Epoch_G_Loss:0.6408
# timer:  1.0350 sec.
# -------------
# Epoch 298/300
# -------------
# (train)
# -------------
# epoch 298 || Epoch_D_Loss:0.0196 ||Epoch_G_Loss:0.6387
# timer:  1.0023 sec.
# -------------
# Epoch 299/300
# -------------
# (train)
# -------------
# epoch 299 || Epoch_D_Loss:0.0093 ||Epoch_G_Loss:0.6108
# timer:  1.0005 sec.
# 총 반복 횟수:  2101

# %%
# 생성 이미지와 훈련 데이터 시각화
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 입력 난수 생성
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)
fake_images = G_update(fixed_z.to(device))

# 훈련 데이터
batch_iterator = iter(train_dataloader) # 반복자로 변환
imges = next(batch_iterator) # 1번째 요소 꺼내기

# 출력
flg = plt.figure(figsize = (15, 15))
for i in range(0, 5):
  # 상단에 훈련 데이터를,
  plt.subplot(2, 5, i+1)
  plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

  # 하단에 생성 데이터 표시
  plt.subplot(2, 5, 5+i+1)
  plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # AnoGAN 본체

# %%
def Anomaly_score(x, fake_img, D, Lambda = 0.1):

  # 테스트 화상 x와 생성 화상 fake_img의 픽셀 수준의 차이의 절대 값을 계산하여, 미니 배치마다 합을 구한다
  residual_loss = torch.abs(x-fake_img)
  residual_loss = residual_loss.view(residual_loss.size()[0], -1)
  residual_loss = torch.sum(residual_loss, dim=1)

  # 테슽 화상 x와 생성 화상 fake_img를 식별기 D에 입력하여, 특징량 맵을 꺼낸다
  _, x_feature = D(x)
  _, G_feature = D(fake_img)

  # 테스트 화상 x와 생성 화상 fake_img의 특징량의 차이의 절대값을 계산하여, 미니 배치마다 합을 구한다
  discrimination_loss = torch.abs(x_feature-G_feature)
  discrimination_Loss = discrimination_loss.view(
      discrimination_loss.size()[0],-1)
  discrimination_Loss = torch.sum(discrimination_loss, dim = 1)

  # 미니 배치마다 2종류의 손실을 더한다
  loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_Loss

  # 미니 배치 전부의 손실을 구한다
  total_loss = torch.sum(loss_each)

  return total_loss, loss_each, residual_loss

# %% [markdown]
# # 테스트 화상으로 이상 탐지

# %%
# 테스트용 DataLoader 작성
def make_test_datapath_list():
  """학습 및 검증 화상 데이터와 어노테이션 데이터의 파일 경로 리스트를 작성한다."""

  train_img_lis = list() # 화상 파일 경로를 저장

  for img_idx in range(5):
      img_path = "./data/test/img_7_" + str(img_idx) + '.jpg'
      train_img_list.append(img_path)

      img_path = "./data/test/img_8_" + str(img_idx) + '.jpg'
      train_img_list.append(img_path)

      img_path = "./data/test/img_2_" + str(img_idx) + '.jpg'
      train_img_list.append(img_path)

  return train_img_list


# 파일 리스트를 작성
test_img_list = make_test_datapath_list()

# Dataset 작성
mean = (0.5, )
std = (0.5, )
test_dataset = GAN_Img_Dataset(
    file_list = test_img_list, transform = ImageTransform(mean, std)
)

# DataLoader 작성
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size = batch_size, shuffle = False
)

# %%
# 테스트 데이터 확인
batch_iterator = iter(test_dataloader) # 반복자로 변환



# 첫번째 미니 배치를 꺼낸다
fig = plt.figure(figsize = (15, 6))
for i in range(0, 5):
  plt.subplot(2, 5, i+1)
  plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
# 이상 탐지할 화상
x = imges[0:5]
x = x.to(device)

# 이상 탐지할 화상을 생성하기 위한 초기 난수
z = torch.randn(5, 20).to(device)
z = z.view(z.size(0), z.size(1), 1, 1)

# 변수 z를 미분할 수 있도록, requires_grad를 True로 설정
z.requires_grad = True

# 변수 z를 갱신할 수 있도록, z의 최적화 함수를 구한다
z_optimizer = torch.optim.Adam([z], lr = 1e-3)

# z를 구한다
for epoch in range(5000+1):
  fake_img = G_update(z)
  loss, _, _ = Anomaly_score(x, fake_img, D_update, Lambda = 0.1)

  z_optimizer.zero_grad()
  loss.backward()
  z_optimizer.step()

  if epoch % 1000 == 0:
    print('epoch {} || loss_total:{:.0f}'.format(epoch, loss.item()))
# Out:
# epoch 0 || loss_total:6691
# epoch 1000 || loss_total:4479
# epoch 2000 || loss_total:3755
# epoch 3000 || loss_total:2363
# epoch 4000 || loss_total:2144
# epoch 5000 || loss_total:2043

# %%
# 화상 생성
G_update.eval()
fake_img = G_update(z)

# 손실을 구한다
loss, loss_each, residual_loss_each = Anomaly_score(
    x, fake_img, D_update, Lambda = 0.1)

# 손실 계산, 총 손실
loss_each = loss_each.cpu().detach().numpy()
print("total loss: ", np.round(loss_each, 0))

# 화상을 시각화
fig = plt.figure(figsize = (15, 6))
for i in range(0, 5):
  # 상단에 테스트 데이터를,
  plt.subplot(2, 5, i+1)
  plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

  # 하단에 생성 데이터를 표시
  plt.subplot(2, 5, 5+i+1)
  plt.imshow(fake_img[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss:  [364. 354. 400. 371. 555.]
